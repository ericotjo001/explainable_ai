# %%
import os, sys
import general_config 
print(general_config.ROOTDIR)
os.chdir(general_config.ROOTDIR)
# Out:
# D:/Desktop@D/xai_basic

# %%
from analysis.xai_roc_analysis import mass_analysis_0002
# %matplotlib inline

# %%
workflow_folder = 'checkpoint/nscc.workflow1_0001v0.4.4.20200902'
config_data = {
    'folder_dir': '%s/%s'%(str(general_config.ROOTDIR),str(workflow_folder)) ,
    'model_name':'workflow1_0001',
    'xai_modes': [
        'Saliency', 
        # 'IntegratedGradients', # MEMORY ISSUE*
        'InputXGradient', 
        'DeepLift', 
        'GuidedBackprop', 
        'GuidedGradCam',
        'Deconvolution', 

        'GradientShap',
        'DeepLiftShap',
    ],
    'branch_name_labels': [1,2,3,4,5],
}

# %%
mass_analysis_0002(config_data=config_data,  do_plot=True,  csv_ext='csv',
    xlim=(0.0,0.12), ylim=(0.,0.04), markersize=None,fontsize=16,
    figsize=(5,3),legend_bbox_to_anchor=(1.6,1), set_legend=True )
mass_analysis_0002(config_data=config_data,  do_plot=True,  csv_ext='csv',
    xlim=None, ylim=None,markersize=3,fontsize=14,
    figsize=(6,5), set_legend=False )

# %%
workflow_folder2 = 'checkpoint/nscc.workflow2_0001v0.4.4.20200902'
config_data2 = {
    'folder_dir': '%s/%s'%(str(general_config.ROOTDIR),str(workflow_folder2)) ,
    'model_name':'workflow2_0001',
    'xai_modes': [
        'Saliency', 
        # 'IntegratedGradients', # MEMORY ISSUE*
        'InputXGradient', 
        'DeepLift', 
        'GuidedBackprop', 
        'GuidedGradCam',
        'Deconvolution', 

        'GradientShap',
        'DeepLiftShap',
    ],
    'branch_name_labels': [1,2,3,4,5],
}

# %%
mass_analysis_0002(config_data=config_data2,  do_plot=True,  csv_ext='csv',
    xlim=(0.02,0.3), ylim=(0.,0.12), markersize=None,fontsize=16,
    figsize=(5,3),legend_bbox_to_anchor=(1.6,1), set_legend=True )
mass_analysis_0002(config_data=config_data2,  do_plot=True,  csv_ext='csv',
    xlim=None, ylim=None,markersize=3,fontsize=14,
    figsize=(6,5), set_legend=False )

# %%
workflow_folder3 = 'checkpoint/nscc.workflow3_0001v0.4.4.20200902'
config_data3 = {
    'folder_dir': '%s/%s'%(str(general_config.ROOTDIR),str(workflow_folder3)) ,
    'model_name':'workflow3_0001',
    'xai_modes': [
        'Saliency', 
        # 'IntegratedGradients', # MEMORY ISSUE*
        'InputXGradient', 
        'DeepLift', 
        'GuidedBackprop', 
        'GuidedGradCam',
        'Deconvolution', 

        'GradientShap',
        'DeepLiftShap',
    ],
    'branch_name_labels': [1,2,3,4,5],
}

# %%
mass_analysis_0002(config_data=config_data3,  do_plot=True,  csv_ext='csv',
    xlim=(0.02,0.3), ylim=(0.,0.12), markersize=None,fontsize=16,
    figsize=(5,3),legend_bbox_to_anchor=(1.6,1), set_legend=True )
mass_analysis_0002(config_data=config_data3,  do_plot=True,  csv_ext='csv',
    xlim=None, ylim=None,markersize=3,fontsize=14,
    figsize=(6,5), set_legend=False )
