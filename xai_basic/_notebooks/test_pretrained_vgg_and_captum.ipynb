# %%
import os, sys
import general_config 
print(general_config.ROOTDIR)
sys.path.append(general_config.ROOTDIR)

import torch
import torch.nn as nn
import numpy as np
from model.adjusted_vgg import AdjVGG

# %%
from captum.attr import IntegratedGradients ,GradientShap, Saliency, Occlusion, DeepLiftShap, InputXGradient
from captum.attr import DeepLift, GuidedBackprop, GuidedGradCam, Deconvolution, FeatureAblation

# %%
import matplotlib.pyplot as plt
def create_comparison(x,heatmap, vmax=1.,vmin=1.,this_title=None):
    # x is torch tensor like (C,H,W)
    plt.figure(figsize=(12,12))
    counter = 1
    x1 = x.clone().detach().cpu().numpy().transpose(1,2,0)
    h1 = heatmap.clone().detach().cpu().numpy().transpose(1,2,0)
    for i in range(4):            
        plt.gcf().add_subplot(1,4,counter)
        if i == 0:
            plt.gca().imshow(x1)
            plt.title('%s'%(str(this_title)))
        else:
            # 3 channels of the heatmaps
            # print('h1:',np.max(h1),np.min(h1), h1.shape)
            plt.gca().imshow(h1[:,:,i-1], cmap='bwr', vmax=vmax,vmin=vmin) 
        counter += 1
    plt.show()

# %%
this_device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")    

N = 4
x = torch.tensor(np.random.uniform(0,1,size=(N,3,224,224))).to(torch.float).to(device=this_device)
x[:2,1,100:120,100:120] = x[:2,1,100:120,100:120]* 0. + 1.
y0 = [0,0,1,1] # np.random.randint(2,size=(N,))
print(y0)
# Out:
# [0, 0, 1, 1]

# %%
net = AdjVGG().to(device=this_device)
y = net(x)
print(y.shape)
# Out:
# torch.Size([4, 10])

# %%
def quick_setup(attrmodel, x,y, option=None):
    x.requires_grad=True
    net.zero_grad()
    for i in range(len(x)): # iterate thru batch number (otherwise too memory consuming)
        if option == 'GradientShap':
            baseline_dist = torch.randn(x.shape).to(device=this_device) * 0.001
            attr = attrmodel.attribute(x[i:i+1], target = y0[i], baselines=baseline_dist)
        elif option == 'DeepLifShap':
            baseline_dist = torch.randn(x.shape).to(device=this_device) * 0.001
            attr = attrmodel.attribute(x[i:i+1], target = y0[i], baselines=baseline_dist)
        elif option == 'Occlusion':
            attr = attrmodel.attribute(x[i:i+1], target = y0[i], sliding_window_shapes=(3,40, 40),strides = (3, 20,20))
        elif option == 'FeatureAblation':
            feature_mask = torch.tensor(0.1*np.ones((3,64,64))).to(torch.int64).to(device=this_device)
            attr = attrmodel.attribute(x[i:i+1], target = y0[i], feature_mask=feature_mask)
        else:
            attr = attrmodel.attribute(x[i:i+1], target = y0[i])

        this_min, this_max = torch.max(attr).item(), torch.min(attr).item()
        heatmap_magnitude = np.max((np.abs(this_min), np.abs(this_max)))
        print('attr.shape:%s, max:%s, min:%s'%(str(attr.shape), str(this_max),str(this_min)))
        this_title = 'hmag:%s'%(str(np.round(heatmap_magnitude,5)))
        create_comparison(x[i].cpu(),heatmap=attr[0], vmax=heatmap_magnitude,vmin=-heatmap_magnitude,
                          this_title=this_title) # grads still in (1,C,H,W)

# %% [markdown]
# ## 1.
# net.zero_grad()
# quick_setup(IntegratedGradients(net), x.clone().detach(), y0)

# %%
## 2
net.zero_grad()
quick_setup(Saliency(net), x.clone().detach(), y0)
# Out:
# attr.shape:torch.Size([1, 3, 224, 224]), max:2.4883775040507317e-09, min:0.015708815306425095
# attr.shape:torch.Size([1, 3, 224, 224]), max:1.7280399333685637e-11, min:0.0002822080859914422
# attr.shape:torch.Size([1, 3, 224, 224]), max:1.7962520360015333e-11, min:0.00020049797603860497
# attr.shape:torch.Size([1, 3, 224, 224]), max:5.17843545821961e-11, min:0.0002212291583418846

# %% [markdown]
# ## 3.
# net.zero_grad()
# quick_setup(DeepLift(net), x.clone().detach(), y0)

# %% [markdown]
# ## 4.
# net.zero_grad()
# quick_setup(DeepLiftShap(net), x.clone().detach(), y0, option='DeepLifShap')

# %%
## 5.
net.zero_grad()
quick_setup(GradientShap(net), x.clone().detach(), y0, option='GradientShap')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-1d3150c5d4b1> in <module>
#       1 ## 5.
#       2 net.zero_grad()
# ----> 3 quick_setup(GradientShap(net), x.clone().detach(), y0, option='GradientShap')
#
# <ipython-input-6-d375ed2c27fd> in quick_setup(attrmodel, x, y, option)
#       5         if option == 'GradientShap':
#       6             baseline_dist = torch.randn(x.shape).to(device=this_device) * 0.001
# ----> 7             attr = attrmodel.attribute(x[i:i+1], target = y0[i], baselines=baseline_dist)
#       8         elif option == 'DeepLifShap':
#       9             baseline_dist = torch.randn(x.shape).to(device=this_device) * 0.001
#
# ~\AppData\Roaming\Python\Python36\site-packages\captum\attr\_core\gradient_shap.py in attribute(self, inputs, baselines, n_samples, stdevs, target, additional_forward_args, return_convergence_delta)
#     261             target=target,
#     262             additional_forward_args=additional_forward_args,
# --> 263             return_convergence_delta=return_convergence_delta,
#     264         )
#     265
#
# ~\AppData\Roaming\Python\Python36\site-packages\captum\attr\_core\noise_tunnel.py in attribute(self, inputs, nt_type, n_samples, stdevs, draw_baseline_from_distrib, **kwargs)
#     282         # smoothgrad_Attr(x) = 1 / n * sum(Attr(x + N(0, sigma^2))
#     283         attributions = self.attribution_method.attribute(
# --> 284             inputs_with_noise if is_inputs_tuple else inputs_with_noise[0], **kwargs
#     285         )
#     286
#
# ~\AppData\Roaming\Python\Python36\site-packages\captum\attr\_core\gradient_shap.py in attribute(self, inputs, baselines, target, additional_forward_args, return_convergence_delta)
#     329         )
#     330         grads = self.gradient_func(
# --> 331             self.forward_func, input_baseline_scaled, target, additional_forward_args
#     332         )
#     333
#
# ~\AppData\Roaming\Python\Python36\site-packages\captum\attr\_utils\gradient.py in compute_gradients(forward_fn, inputs, target_ind, additional_forward_args)
#     101         # torch.unbind(forward_out) is a list of scalar tensor tuples and
#     102         # contains batch_size * #steps elements
# --> 103         grads = torch.autograd.grad(torch.unbind(outputs), inputs)
#     104     return grads
#     105
#
# ~\AppData\Roaming\Python\Python36\site-packages\torch\autograd\__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     155     return Variable._execution_engine.run_backward(
#     156         outputs, grad_outputs, retain_graph, create_graph,
# --> 157         inputs, allow_unused)
#     158
#     159
#
# RuntimeError: CUDA out of memory. Tried to allocate 392.00 MiB (GPU 0; 4.00 GiB total capacity; 1.53 GiB already allocated; 269.01 MiB free; 1.69 GiB reserved in total by PyTorch)

# %%
## 6.
net.zero_grad()
quick_setup(InputXGradient(net), x.clone().detach(), y0, )

# %%
## 7.
net.zero_grad()
quick_setup(GuidedBackprop(net), x.clone().detach(), y0, )

# %%
## 8.
net.zero_grad() 
quick_setup(GuidedGradCam(net, getattr(net.backbone.features,'0')), x.clone().detach(), y0, )

# %%
## 9.
net.zero_grad()
quick_setup(Deconvolution(net), x.clone().detach(), y0, )
