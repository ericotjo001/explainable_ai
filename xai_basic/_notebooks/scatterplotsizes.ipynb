# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array(range(10))
y = x*0+1

# %%
# %matplotlib inline
plt.figure()
plt.scatter(x,y,s=np.exp(x)+1, facecolor='none',edgecolor='b')
plt.show()
