# %%
import os, sys
import general_config 
print(general_config.ROOTDIR)
os.chdir(general_config.ROOTDIR)
# Out:
# D:/Desktop@D/xai_basic

# %%
from analysis.xai_mass_analysis import mass_analysis_0001
# %matplotlib inline

# %%
workflow_folder = 'checkpoint/nscc.workflow2_0001v0.4.4.20200902'
config_data = {
    'folder_dir': '%s/%s'%(str(general_config.ROOTDIR),str(workflow_folder)) ,
    'model_name':'workflow2_0001',
    'xai_modes': [
        'Saliency', 
        # 'IntegratedGradients', # MEMORY ISSUE*
        'InputXGradient', 
        'DeepLift', 
        'GuidedBackprop', 
        'GuidedGradCam',
        'Deconvolution', 

        'GradientShap',
        'DeepLiftShap',
    ],
    'branch_name_labels': [1,2,3,4,5],
}

config_data2 = {
    'folder_dir': '%s/%s'%(str(general_config.ROOTDIR),str(workflow_folder)) ,
    'model_name':'workflow2_0001',
    'xai_modes': [
        'Saliency', 
        # 'IntegratedGradients', # MEMORY ISSUE*
        'InputXGradient', 
        'DeepLift', 
        'GuidedBackprop', 
        'GuidedGradCam',
        'Deconvolution', 

        'GradientShap',
        'DeepLiftShap',
    ],
    'branch_name_labels': [1,2,3,4,5],
}

# %% [markdown]
# # Part 1 No clamp

# %% [markdown]
# ## Part 1.1

# %%
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', sample_mode=sample_mode,
                   xlim=[0,0.6], ylim=[-0.01,0.75],plot_mode='recall_vs_precision', markersize=6, 
                   figsize=(8,6), legend_bbox_to_anchor=(1.5,1),fontsize=14,print_values=False, set_legend=True)
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', sample_mode=sample_mode,
                   xlim=[0.15,0.3], ylim=[0.03,0.08],plot_mode='recall_vs_precision', markersize=9, 
                   figsize=(4,3), legend_bbox_to_anchor=(1.5,1),fontsize=16,print_values=False, set_legend=False)

# %% [markdown]
# ## Part 1.2
# Recall vs precision best

# %%
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', sample_mode=sample_mode,
                   xlim=[0,0.6], ylim=[-0.01,0.75],plot_mode='recall_vs_precision_best', markersize=9,
                   figsize=(8,6), legend_bbox_to_anchor=(1.5,1),fontsize=14,print_values=False, set_legend=True)

# %% [markdown]
# ## Part 1.3
# acc_vs_precision

# %%
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', sample_mode=sample_mode,
                   xlim=[0,0.7], ylim=[0.,0.95],plot_mode='acc_vs_precision', markersize=9,
                   figsize=(8,6), legend_bbox_to_anchor=(1.5,1),print_values=False,  set_legend=True)
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', sample_mode=sample_mode,
                   xlim=[0.1,0.4], ylim=[0.8,0.9],plot_mode='acc_vs_precision', markersize=9,
                   figsize=(4,3), legend_bbox_to_anchor=(1.5,1),print_values=False,  set_legend=False)

# %% [markdown]
# # Part 2 with clamp

# %% [markdown]
# ## Part 2.1
# recall vs precision clamp

# %%
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data2, do_plot=True,csv_ext='clamp.csv', sample_mode=sample_mode,
                   xlim=[0,0.6], ylim=[-0.01,0.75],plot_mode='recall_vs_precision', markersize=6, 
                   figsize=(8,6), legend_bbox_to_anchor=(1.5,1),fontsize=14,print_values=False, set_legend=True)
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data2, do_plot=True,csv_ext='clamp.csv', sample_mode=sample_mode,
                   xlim=[0.14,0.2], ylim=[0.002,0.15],plot_mode='recall_vs_precision', markersize=9, 
                   figsize=(4,3), legend_bbox_to_anchor=(1.5,1),fontsize=16,print_values=False, set_legend=False)

# %% [markdown]
# ## Part 2.2
# recall vs precision best clamp

# %%
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data2, do_plot=True,csv_ext='clamp.csv', sample_mode=sample_mode,
                   xlim=[0,0.6], ylim=[-0.01,0.75],plot_mode='recall_vs_precision_best', markersize=9,
                   figsize=(8,6), legend_bbox_to_anchor=(1.5,1),fontsize=14,print_values=False, set_legend=True)

# %% [markdown]
# ## Part 2.3
# acc_vs_precision best clamp

# %%
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data2, do_plot=True,csv_ext='clamp.csv', sample_mode=sample_mode,
                   xlim=[0,0.8], ylim=[0.,0.95],plot_mode='acc_vs_precision', markersize=9,
                   figsize=(8,6), legend_bbox_to_anchor=(1.5,1),print_values=False,  set_legend=True )
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data2, do_plot=True,csv_ext='clamp.csv', sample_mode=sample_mode,
                   xlim=[0.1,0.2], ylim=[0.897,0.898],plot_mode='acc_vs_precision', markersize=9,
                   figsize=(4,3), legend_bbox_to_anchor=(1.5,1), set_legend=False,print_values=False)

# %% [markdown]
# # Part 3 No clamp exclude empty

# %% [markdown]
# ## Part 3.1 recall vs precision

# %%
mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', sample_mode=None, exclude_empty=True,
               xlim=[0,0.6], ylim=[-0.01,0.75],plot_mode='recall_vs_precision', markersize=6, 
               figsize=(8,6), legend_bbox_to_anchor=(1.5,1),fontsize=14,print_values=False, set_legend=True)

mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', sample_mode=None,exclude_empty=True,
               xlim=[0.1,0.4], ylim=[0.015,0.1],plot_mode='recall_vs_precision', markersize=9, 
               figsize=(4,3), legend_bbox_to_anchor=(1.5,1),fontsize=16,print_values=False, set_legend=False)
