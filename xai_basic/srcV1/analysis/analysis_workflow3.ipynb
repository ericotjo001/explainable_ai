# %%
import os, sys
import general_config 
print(general_config.ROOTDIR)
os.chdir(general_config.ROOTDIR)

# %%
from analysis.xai_mass_analysis import mass_analysis_0001
# %matplotlib inline

# %%
workflow_folder = 'checkpoint/nscc.workflow3_0001v0.4.4.20200902'
config_data = {
    'folder_dir': '%s/%s'%(str(general_config.ROOTDIR),str(workflow_folder)) ,
    'model_name':'workflow3_0001',
    'xai_modes': [
        'Saliency', 
        # 'IntegratedGradients', # MEMORY ISSUE*
        'InputXGradient', 
        'DeepLift', 
        'GuidedBackprop', 
        'GuidedGradCam',
        'Deconvolution', 

        'GradientShap',
        'DeepLiftShap',
    ],
    'branch_name_labels': [1,2,3,4,5],
}

config_data2 = {
    'folder_dir': '%s/%s'%(str(general_config.ROOTDIR),str(workflow_folder)) ,
    'model_name':'workflow3_0001',
    'xai_modes': [
        'Saliency', 
        # 'IntegratedGradients', # MEMORY ISSUE*
        'InputXGradient', 
        'DeepLift', 
        'GuidedBackprop', 
        'GuidedGradCam',
        'Deconvolution', 

        'GradientShap',
        'DeepLiftShap',
    ],
    'branch_name_labels': [1,2,3,4,5],
}

# %% [markdown]
# # Part 1 No clamp

# %% [markdown]
# ## Part 1.1
# Recall vs precision

# %%
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', 
                   xlim=[0,0.6], ylim=[-0.01,0.75],plot_mode='recall_vs_precision', markersize=6, sample_mode=sample_mode,
                   figsize=(8,6), legend_bbox_to_anchor=(1.5,1),fontsize=14, set_legend=True,print_values=False)
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', 
                   xlim=[0.1,0.4], ylim=[0.01,0.04],plot_mode='recall_vs_precision', markersize=9, sample_mode=sample_mode,
                   figsize=(4,3), legend_bbox_to_anchor=(1.5,1),fontsize=16,print_values=False, set_legend=False)

# %% [markdown]
# ## Part 1.2
# Recall vs precision best

# %%
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', sample_mode=sample_mode,
                   xlim=[0,0.6], ylim=[-0.01,0.75],plot_mode='recall_vs_precision_best', markersize=6, 
                   figsize=(8,6), legend_bbox_to_anchor=(1.5,1),fontsize=14, set_legend=True,print_values=False)
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', 
                   xlim=[0.2,0.3], ylim=[0.05,0.15],plot_mode='recall_vs_precision_best', markersize=9, sample_mode=sample_mode,
                   figsize=(4,3), legend_bbox_to_anchor=(1.5,1),fontsize=16,print_values=False, set_legend=False)

# %% [markdown]
# ## Part 1.3

# %%
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', sample_mode=sample_mode,
                   xlim=[0,0.8], ylim=[0.,0.95],plot_mode='acc_vs_precision', markersize=9,
                   figsize=(8,6), legend_bbox_to_anchor=(1.5,1), set_legend=False,print_values=False)
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', sample_mode=sample_mode,
                   xlim=None, ylim=None,plot_mode='acc_vs_precision', markersize=9,
                   figsize=(4,3), legend_bbox_to_anchor=(1.5,1), set_legend=False,print_values=False)

# %% [markdown]
# # Part 2 with clamp

# %% [markdown]
# ## Part 2.1
# recall vs precision clamp

# %%
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data2, do_plot=True,csv_ext='clamp.csv', 
                   xlim=[0,0.6], ylim=[-0.01,0.75],plot_mode='recall_vs_precision', markersize=6, sample_mode=sample_mode,
                   figsize=(8,6), legend_bbox_to_anchor=(1.5,1),fontsize=14, set_legend=True,print_values=False)
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data2, do_plot=True,csv_ext='clamp.csv', 
                   xlim=[0.15,0.25], ylim=[0.002,0.05],plot_mode='recall_vs_precision', markersize=9, sample_mode=sample_mode,
                   figsize=(4,3), legend_bbox_to_anchor=(1.5,1),fontsize=16,print_values=False, set_legend=False)

# %% [markdown]
# ## Part 2.2
# recall vs precision best clamp

# %%
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data2, do_plot=True,csv_ext='clamp.csv', sample_mode=sample_mode,
                   xlim=[0,0.6], ylim=[-0.01,0.75],plot_mode='recall_vs_precision_best', markersize=6, 
                   figsize=(8,6), legend_bbox_to_anchor=(1.5,1),fontsize=14, set_legend=True,print_values=False)

# %% [markdown]
# ## Part 2.3
# acc_vs_precision best clamp

# %%
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data2, do_plot=True,csv_ext='clamp.csv', sample_mode=sample_mode,
                   xlim=[0,0.8], ylim=[0.,0.95],plot_mode='acc_vs_precision', markersize=9,
                   figsize=(8,6), legend_bbox_to_anchor=(1.5,1),set_legend=False,print_values=False )
for sample_mode in [None, 'only_correct_pred']:
    mass_analysis_0001(config_data=config_data2, do_plot=True,csv_ext='clamp.csv', sample_mode=sample_mode,
                   xlim=None, ylim=[0.89,0.9],plot_mode='acc_vs_precision', markersize=9,
                   figsize=(4,3), legend_bbox_to_anchor=(1.5,1), set_legend=False,print_values=False)

# %% [markdown]
# # Part 3 No clamp exclude empty

# %% [markdown]
# ## Part 3.1 recall vs precision

# %%
mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', exclude_empty=True,
               xlim=[0,0.6], ylim=[-0.01,0.75],plot_mode='recall_vs_precision', markersize=6, sample_mode=None,
               figsize=(8,6), legend_bbox_to_anchor=(1.5,1),fontsize=14, set_legend=True,print_values=False)

mass_analysis_0001(config_data=config_data, do_plot=True,csv_ext='csv', exclude_empty=True,
               xlim=[0.15,0.32], ylim=[-0.01,0.1],plot_mode='recall_vs_precision', markersize=9, sample_mode=None,
               figsize=(4,3), legend_bbox_to_anchor=(1.5,1),fontsize=16,print_values=False, set_legend=False)
